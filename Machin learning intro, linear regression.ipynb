# %% [markdown]
# # Machine Learning

# %% [markdown]
# #### machine learning is a subset of Artificial Intelligence that provides statistical tools to explore data.
# #### machine learning gives the computers the ability to learn and make decisions based on data
# #### Machine learning and AI are often used interchangeably, but they dont mean the same thing.
# #### An important distinction is that although all machine learning is AI. not all AI is machine learning
# #### Today,  machine learning is at work around us. When we interact with Banks, Shop online or use social media, machine learning algorithm comes into play to make our experience efficient, smooth and secure.
# #### Machine learning and the technology around it are developing rapidly, and we are beginning to scratch the surface of its capabilities

# %% [markdown]
# # Supervised machine learning

# %% [markdown]
# #### Supervised machine learning algorithms are the commonly used. With this model, a data scientist acts as a guide and teaches the algorithm what conclusions it should make. Just as a child learns to identify fruits by memorizing them in a picture book.
#
#
# #### In Supervised learning, the algorithm is trained by a dataset that is already labeled and has predefined output.

# %% [markdown]
# # Supervised learning is where you:

# %% [markdown]
# #### Have labeled data which means we already know the corresponding output for each input.
# #### Use an algorithm to learn the hidden patterns between the inputs and the output.
# #### End to model these hidden patterns by a mapping function.

# %% [markdown]
# # What is linear regression?

# %% [markdown]
# #### Linear regression analysis is used to predict the value of a variable based on the value of another variable.
# #### The variable you want to predict is called the dependent variable.
# #### The variable you are using to predict the other variable's value is called the independent variable.

# %% [markdown]
# # Steps
#
# #### 1.  load the dataset

# %%
import pandas as pd

record = pd.read_csv("Breast Cancer Updated", delimiter="\t")
record
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# #### 2. Data pre-processing

# %% [markdown]
# ##### a. Extract feature names and target from the dataset:
#
#
#  #### In machine learning, a feature is data that's used as the input for ML models to make predictions also called independent variable
#
#   #### In machine learning, a target is data that's used as the input for ML models to make predictions also called dependent variable

# %%
independent = record.iloc[0:, 0:30]   #features
independent
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
dependent = record.iloc[0:, -1]
dependent
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: Decision, Length: 569, dtype: int64

# %% [markdown]
# #### 3. Splitting the dataset into train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.5, random_state=0)

# %% [markdown]
# #### 4. Building a linear regression model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# #### 5. Model fitting

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### 6. Evaluating and Improving the Regression Model

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([ 0.18534468,  0.82184834,  0.95895725,  0.80950701,  0.92909707,
#         0.89839243,  1.07148023,  1.00622703,  1.20749483,  1.04627819,
#         0.76302717,  0.80672336,  1.33007425,  0.73450242,  0.63898046,
#         0.16596647,  1.13931916,  0.11760207,  0.12742299, -0.24758589,
#         0.16057509,  0.27059333,  0.79156168,  0.96462189,  0.13594118,
#         0.86093583,  1.0845756 ,  0.35965697,  0.89622045,  0.01141206,
#         1.06483098,  0.05751453,  0.68359562,  0.42109807,  1.31456562,
#         0.04524998,  0.66915981,  0.32890636,  0.7873518 , -0.03532936,
#         0.41537619,  1.2293341 ,  0.5005572 ,  1.21922921,  0.59895718,
#        -0.26590581,  1.39906962,  0.82174329,  0.95007979,  0.06046699,
#         0.65016183,  0.69234056,  0.2027451 ,  0.9001073 ,  0.97290473,
#         0.88131778,  1.11293419,  0.79565852,  0.82143399,  0.05703427,
#         0.14915299,  0.16049797,  1.17961092,  0.89310526,  0.01455624,
# ...

# %%
dependent
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: Decision, Length: 569, dtype: int64
